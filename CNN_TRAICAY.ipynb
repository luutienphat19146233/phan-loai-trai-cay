# %% [markdown]
# <a href="https://colab.research.google.com/github/luutienphat19146233/phan-loai-trai-cay/blob/main/CNN_TRAICAY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import SGD, RMSprop,Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# Chuyển đến file Google Drive chứa bộ ảnh đã tạo
# %cd"/content/drive/MyDrive/BaitapAI/tuan14/Trai cay"
# Out:
# /content/drive/MyDrive/BaitapAI/tuan14/Trai cay

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train_datagen.flow_from_directory('/content/drive/MyDrive/BaitapAI/tuan14/Trai cay/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 500 images belonging to 10 classes.

# %%
# Tạo bộ dữ liệu validation set
validation=train_datagen.flow_from_directory('/content/drive/MyDrive/BaitapAI/tuan14/Trai cay/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 100 images belonging to 10 classes.

# %%
#các nhãn có trong bộ dữ liệu train
training_set.class_indices
# Out:
# {'bơ': 0,
#  'bưởi': 1,
#  'chôm chôm': 2,
#  'dừa': 3,
#  'măng cụt': 4,
#  'mận hà nội': 5,
#  'sầu riêng': 6,
#  'thanh long': 7,
#  'vải thiều': 8,
#  'vú sữa': 9}

# %%
#các nhãn có trong bộ dữ liệu validation
validation.class_indices
# Out:
# {'bơ': 0,
#  'bưởi': 1,
#  'chôm chôm': 2,
#  'dừa': 3,
#  'măng cụt': 4,
#  'mận hà nội': 5,
#  'sầu riêng': 6,
#  'thanh long': 7,
#  'vải thiều': 8,
#  'vú sữa': 9}

# %%
model=Sequential()
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 32 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(32,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 5,596,842
# Trainable params: 5,596,842
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
# Gán biến lại để vẽ đồ thị, với 500 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), khi sai số không thay đổi trong 20 lần học thì sẽ␣ dừng học 
history=model.fit(training_set,epochs=100,batch_size=128,verbose=1, validation_data=validation, callbacks=[EarlyStopping(monitor='val_loss', patience=20)]) # verbose=1 để hiển thị quá trinh học
# Out:
# Epoch 1/100
# 16/16 [==============================] - 138s 8s/step - loss: 4.3405 - accuracy: 0.0940 - val_loss: 2.2783 - val_accuracy: 0.2200
# Epoch 2/100
# 16/16 [==============================] - 4s 262ms/step - loss: 2.2130 - accuracy: 0.1800 - val_loss: 2.0084 - val_accuracy: 0.3000
# Epoch 3/100
# 16/16 [==============================] - 4s 267ms/step - loss: 2.0207 - accuracy: 0.1980 - val_loss: 1.9902 - val_accuracy: 0.2400
# Epoch 4/100
# 16/16 [==============================] - 4s 265ms/step - loss: 1.9211 - accuracy: 0.2500 - val_loss: 1.6852 - val_accuracy: 0.4000
# Epoch 5/100
# 16/16 [==============================] - 4s 265ms/step - loss: 1.6964 - accuracy: 0.3860 - val_loss: 1.4797 - val_accuracy: 0.4300
# Epoch 6/100
# 16/16 [==============================] - 4s 264ms/step - loss: 1.5918 - accuracy: 0.4300 - val_loss: 1.4164 - val_accuracy: 0.4500
# Epoch 7/100
# 16/16 [==============================] - 4s 271ms/step - loss: 1.4621 - accuracy: 0.4900 - val_loss: 1.0304 - val_accuracy: 0.6900
# Epoch 8/100
# 16/16 [==============================] - 4s 267ms/step - loss: 1.3187 - accuracy: 0.5400 - val_loss: 1.1187 - val_accuracy: 0.5800
# Epoch 9/100
# 16/16 [==============================] - 4s 267ms/step - loss: 1.3342 - accuracy: 0.5480 - val_loss: 1.0205 - val_accuracy: 0.7000
# Epoch 10/100
# 16/16 [==============================] - 4s 268ms/step - loss: 1.2527 - accuracy: 0.5700 - val_loss: 0.7369 - val_accuracy: 0.7800
# Epoch 11/100
# 16/16 [==============================] - 4s 266ms/step - loss: 0.9947 - accuracy: 0.6440 - val_loss: 0.6856 - val_accuracy: 0.7700
# Epoch 12/100
# 16/16 [==============================] - 4s 269ms/step - loss: 1.0106 - accuracy: 0.6220 - val_loss: 0.7682 - val_accuracy: 0.7500
# Epoch 13/100
# 16/16 [==============================] - 5s 314ms/step - loss: 0.8865 - accuracy: 0.7040 - val_loss: 0.5945 - val_accuracy: 0.7900
# Epoch 14/100
# 16/16 [==============================] - 4s 270ms/step - loss: 0.7745 - accuracy: 0.7400 - val_loss: 0.4322 - val_accuracy: 0.8200
# Epoch 15/100
# 16/16 [==============================] - 4s 266ms/step - loss: 0.8455 - accuracy: 0.6940 - val_loss: 0.6625 - val_accuracy: 0.7600
# Epoch 16/100
# 16/16 [==============================] - 4s 267ms/step - loss: 0.8263 - accuracy: 0.7160 - val_loss: 0.4802 - val_accuracy: 0.8600
# Epoch 17/100
# 16/16 [==============================] - 4s 268ms/step - loss: 0.8290 - accuracy: 0.7140 - val_loss: 0.5332 - val_accuracy: 0.8600
- val_loss: 0.0081 - val_accuracy: 1.0000
# Epoch 94/100
# 16/16 [==============================] - 4s 266ms/step - loss: 0.1057 - accuracy: 0.9680 - val_loss: 0.0559 - val_accuracy: 0.9700
# Epoch 95/100
# 16/16 [==============================] - 4s 270ms/step - loss: 0.1415 - accuracy: 0.9680 - val_loss: 0.0665 - val_accuracy: 0.9700
# Epoch 96/100
# 16/16 [==============================] - 4s 270ms/step - loss: 0.1222 - accuracy: 0.9520 - val_loss: 0.0075 - val_accuracy: 1.0000
# Epoch 97/100
# 16/16 [==============================] - 4s 266ms/step - loss: 0.1013 - accuracy: 0.9580 - val_loss: 0.0277 - val_accuracy: 0.9900
# Epoch 98/100
# 16/16 [==============================] - 4s 264ms/step - loss: 0.1057 - accuracy: 0.9660 - val_loss: 0.0138 - val_accuracy: 1.0000
# Epoch 99/100
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0215 - accuracy: 0.9940 - val_loss: 0.0063 - val_accuracy: 1.0000
# Epoch 100/100
# 16/16 [==============================] - 4s 272ms/step - loss: 0.0278 - accuracy: 0.9920 - val_loss: 0.0085 - val_accuracy: 1.0000

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-49117ccd1508> in <module>()
#       1 # Đánh giá độ chính xác của mô hình
# ----> 2 Score=model.evaluate(training_set,verbose=0)
#       3 print('Train Loss', Score[0])
#       4 print('Train Accuracy', Score[1])
#
# NameError: name 'model' is not defined

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy']) 
plt.plot(history.history['val_accuracy']) 
plt.title('Model Accuracy') 
plt.ylabel('Accuracy') 
plt.xlabel('Epochs') 
plt.legend(['Train','Validation']) 
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
name=['bơ',
 'bưởi',
 'chôm chôm',
 'dừa',
 'măng cụt',
 'mận hà nội',
 'sầu riêng',
 'thanh long',
 'vải thiều',
 'vú sữa']
url='/content/images (4).jpg'
img=load_img(url,target_size=(150,150))
plt.imshow(load_img(url))
plt.xticks([])
plt.yticks([])
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img/255
print(name[np.argmax(model.predict(img))])
# Out:
# vú sữa

# %%
url='/content/images (1).jpg'
img=load_img(url,target_size=(150,150))
plt.imshow(load_img(url))
plt.xticks([])
plt.yticks([])
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img/255
print(name[np.argmax(model.predict(img))])
# Out:
# sầu riêng

# %%
url='/content/tải xuống (11).jpg'
img=load_img(url,target_size=(150,150))
plt.imshow(load_img(url))
plt.xticks([])
plt.yticks([])
img=img_to_array(img)
img=img.reshape(1,150,150,3)
img=img/255
print(name[np.argmax(model.predict(img))])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a1b547fae8c9> in <module>()
#       1 url='/content/tải xuống (11).jpg'
# ----> 2 img=load_img(url,target_size=(150,150))
#       3 plt.imshow(load_img(url))
#       4 plt.xticks([])
#       5 plt.yticks([])
#
# NameError: name 'load_img' is not defined
